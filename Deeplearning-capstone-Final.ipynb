# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import os
import zipfile
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Set random seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Step 1: Load and preprocess data
def load_data(dataset_path, img_size=(224, 224), batch_size=16):
    datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        validation_split=0.2
    )
    train_generator = datagen.flow_from_directory(
        dataset_path, target_size=img_size, batch_size=batch_size,
        class_mode='binary', subset='training', shuffle=True
    )
    val_generator = datagen.flow_from_directory(
        dataset_path, target_size=img_size, batch_size=batch_size,
        class_mode='binary', subset='validation', shuffle=False
    )
    return train_generator, val_generator

# Step 2: Build CNN model
def build_model(input_shape=(224, 224, 3)):
    model = models.Sequential([
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Step 3: Train model
def train_model(model, train_generator, val_generator, epochs=20):
    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)
    ]
    history = model.fit(
        train_generator,
        epochs=epochs,
        validation_data=val_generator,
        callbacks=callbacks
    )
    return history

# Step 4: Evaluate model
def evaluate_model(model, val_generator):
    val_steps = val_generator.samples // val_generator.batch_size
    y_pred = (model.predict(val_generator, steps=val_steps + 1) > 0.5).astype(int).flatten()
    y_true = val_generator.classes[:len(y_pred)]
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=['Bike', 'Car']))
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Bike', 'Car'], yticklabels=['Bike', 'Car'])
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# Step 5: Visualize predictions
def visualize_predictions(model, val_generator, num_images=5):
    images, labels = next(val_generator)
    predictions = model.predict(images)
    plt.figure(figsize=(15, 3))
    for i in range(min(num_images, len(images))):
        plt.subplot(1, num_images, i+1)
        plt.imshow(images[i])
        predicted_class = 'Car' if predictions[i] > 0.5 else 'Bike'
        confidence = predictions[i][0] if predictions[i] > 0.5 else 1 - predictions[i][0]
        plt.title(f'Pred: {predicted_class}\nConf: {confidence:.2f}')
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Main execution
def main():
    # Paths
    zip_path = "/content/images.zip"
    dataset_path = "/content/cars_bikes_dataset"

    # Extract ZIP file
    if not os.path.exists(dataset_path):
        if not os.path.exists(zip_path):
            raise FileNotFoundError("Please upload 'images.zip' to /content/ in Colab.")
        print(f"Extracting {zip_path}...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(dataset_path)
        print("Extraction complete.")

    # Verify directory and subdirectories
    if not os.path.isdir(dataset_path):
        raise NotADirectoryError(f"{dataset_path} is not a directory.")
    required_subdirs = ['Bikes', 'Cars']
    existing_subdirs = [d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))]
    if not all(subdir in existing_subdirs for subdir in required_subdirs):
        raise FileNotFoundError(f"Expected 'Bikes' and 'Cars' subdirectories, found: {existing_subdirs}")

    # Run pipeline
    train_generator, val_generator = load_data(dataset_path)
    model = build_model()
    model.summary()
    history = train_model(model, train_generator, val_generator)
    evaluate_model(model, val_generator)
    visualize_predictions(model, val_generator)

    # Plot training history
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Found 633 images belonging to 2 classes.
# Found 158 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 222, 222, 32)   │           128 │
# ...

# %% [markdown]
# #Dataset
# *Training Set: 633 images, 2 classes (Bike, Car)
#
# *Validation Set: 158 images, 2 classes (Bike, Car)
#
# #Model Architecture
# Type: Sequential Convolutional Neural Network (CNN)
#
# Layers:
#
# *3 Conv2D layers (32, 64, 128 filters) with ReLU activation
#
# *3 BatchNormalization layers
#
# *3 MaxPooling2D layers
#
# *Flatten layer
#
# *Dense layer (128 units, ReLU activation)
#
# *Dropout layer (0.5 rate)
#
# *Output Dense layer (1 unit, sigmoid activation)
#
# Total Parameters: 11,169,985 (42.61 MB)
#
# *Trainable: 11,169,537
#
# *Non-trainable: 448
#
# #Training
# Epochs: 20
#
# Optimizer: Not specified (default learning rate: 0.001)
#
# Loss Function: Binary cross-entropy (inferred from output layer)
#
# Metrics: Accuracy
#
# Performance:
#
# *Training accuracy improved from 69.99% (Epoch 1) to 88.63% (Epoch 20)
#
# *Validation accuracy peaked at 90.51% (Epoch 19) but ended at 78.48% (Epoch 20)
#
# *Validation loss decreased overall, with the lowest at 0.2634 (Epoch 19)
#
# #Evaluation
# Test Set Performance (158 images):
#
# Accuracy: 91.77%
#
# Classification Report:
#
# Bike: Precision: 0.87, Recall: 0.97, F1-score: 0.92 (78 samples)
#
# Car: Precision: 0.97, Recall: 0.86, F1-score: 0.91 (80 samples)
#
# Macro Avg: Precision: 0.92, Recall: 0.92, F1-score: 0.92
#
# Weighted Avg: Precision: 0.92, Recall: 0.92, F1-score: 0.92
#
# #Observations
#
# *The model shows strong performance with 91.77% accuracy on the test set.
#
# *High recall for Bike (0.97) and high precision for Car (0.97) indicate robust class differentiation.
#
# *Validation accuracy fluctuated, peaking at Epoch 19, suggesting potential overfitting or instability in later epochs.
